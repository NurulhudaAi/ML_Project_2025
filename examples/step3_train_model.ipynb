# %%
import joblib
import json
import pandas

import sklearn.neighbors

# %% [markdown]
# # Instructions
#
# - Read **the train data** from the CSV file and properly set the index

# %%
data_train= pandas.read_csv('./data/features.train.csv').set_index('id')
data_train
# Out:
#      duration  credit_amount  age  checking_status_no checking  \
# id
# 253        24           4151   35                          1.0
# 667        48           3609   27                          1.0
# 85         12           1412   29                          1.0
# 969        11           3939   40                          0.0
# 75         12           1526   66                          0.0
# ..        ...            ...  ...                          ...
# 835        12           1082   48                          0.0
# 192        27           3915   36                          0.0
# 629         9           3832   64                          1.0
# 559        18           1928   31                          0.0
# 684        36           9857   31                          0.0
#
#      checking_status_<0  checking_status_0<=X<200  checking_status_>=200  \
# id
# 253                 0.0                       0.0                    0.0
# 667                 0.0                       0.0                    0.0
# 85                  0.0                       0.0                    0.0
# 969                 1.0                       0.0                    0.0
# 75                  1.0                       0.0                    0.0
# ..                  ...                       ...                    ...
# 835                 1.0                       0.0                    0.0
# 192                 0.0                       1.0                    0.0
# 629                 0.0                       0.0                    0.0
# 559                 0.0                       1.0                    0.0
# 684                 0.0                       1.0                    0.0
#
#      credit_history_critical/other existing credit  \
# id
# 253                                            0.0
# 667                                            0.0
# 85                                             1.0
# 969                                            1.0
# 75                                             1.0
# ..                                             ...
# 835                                            0.0
# 192                                            0.0
# 629                                            0.0
# 559                                            1.0
# 684                                            0.0
#
#      credit_history_delayed previously  credit_history_existing paid  ...  \
# id                                                                    ...
# 253                                1.0                           0.0  ...
# 667                                0.0                           0.0  ...
# 85                                 0.0                           0.0  ...
# 969                                0.0                           0.0  ...
# 75                                 0.0                           0.0  ...
# ..                                 ...                           ...  ...
# 835                                0.0                           0.0  ...
# 192                                0.0                           1.0  ...
# 629                                0.0                           1.0  ...
# 559                                0.0                           0.0  ...
# 684                                1.0                           0.0  ...
#
#      residence_since_2  residence_since_3  residence_since_4  \
# id
# 253                0.0                1.0                0.0
# 667                0.0                0.0                0.0
# 85                 1.0                0.0                0.0
# 969                1.0                0.0                0.0
# 75                 0.0                0.0                1.0
# ..                 ...                ...                ...
# 835                0.0                0.0                1.0
# 192                1.0                0.0                0.0
# 629                0.0                0.0                1.0
# 559                1.0                0.0                0.0
# 684                0.0                1.0                0.0
#
#      existing_credits_1  existing_credits_2  existing_credits_3  \
# id
# 253                 0.0                 1.0                 0.0
# 667                 1.0                 0.0                 0.0
# 85                  0.0                 1.0                 0.0
# 969                 0.0                 1.0                 0.0
# 75                  0.0                 1.0                 0.0
# ..                  ...                 ...                 ...
# 835                 0.0                 1.0                 0.0
# 192                 1.0                 0.0                 0.0
# 629                 1.0                 0.0                 0.0
# 559                 0.0                 1.0                 0.0
# 684                 0.0                 1.0                 0.0
#
#      existing_credits_4  num_dependents_1  num_dependents_2  label
# id
# 253                 0.0               1.0               0.0    0.0
# 667                 0.0               1.0               0.0    0.0
# 85                  0.0               1.0               0.0    0.0
# 969                 0.0               0.0               1.0    0.0
# 75                  0.0               1.0               0.0    0.0
# ..                  ...               ...               ...    ...
# 835                 0.0               1.0               0.0    1.0
# 192                 0.0               0.0               1.0    1.0
# 629                 0.0               1.0               0.0    0.0
# 559                 0.0               1.0               0.0    1.0
# 684                 0.0               0.0               1.0    0.0
#
# [750 rows x 72 columns]

# %% [markdown]
# # Instructions
#
# - Instantiate a `sklearn.neighbors.KNeighborsClassifier` model with the following configurations
# ```
#     n_neighbors=5,
#     weights='uniform',
#     p=2,
# ```
# - Fit the model with data columns properly selected
# - Use `joblib.dump` to save the model to `./model/model.joblib`
# - Also, use `.get_params`, `json.dump` to save the model configuration to  `./model/config.json`

# %%
X_train = data_train.drop(['label'], axis='columns')
y_train = data_train['label']

# %%
model= sklearn.neighbors.KNeighborsClassifier(
     n_neighbors=5,
    weights='uniform', 
    p=2, 
)
model
# Out:
# KNeighborsClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
joblib.dump(model, './model/model.joblib')
# Out:
# ['./model/model.joblib']

# %%
config = model.get_params()

# %%
with open('./model/config.json', 'w') as f:
    json.dump(config, f, indent=4)
