# %%
import numpy
import pandas
import joblib
import json
import seaborn

import sklearn

# %matplotlib inline

# %%
data_test = pandas.read_csv('../data/features.test.csv').set_index('id')
data_test
# Out:
#        age-group  education-num   capitalgain  capitalloss  hoursperweek  \
# id
# 12849  -0.730900       0.988332  1.804794e+00    -0.231881     -0.051599
# 1460   -1.529352      -3.635984 -3.275813e-01    -0.231881      1.094355
# 13594   0.067553      -0.553107 -3.275813e-01    -0.231881     -0.051599
# 14400   0.866005      -0.553107  5.918530e-17    -0.231881     -0.051599
# 14333   0.067553      -0.553107 -3.275813e-01    -0.231881      1.094355
# ...          ...            ...           ...          ...           ...
# 21121   0.866005      -0.553107 -3.275813e-01    -0.231881     -0.051599
# 12348   0.067553       0.988332  3.937169e+00    -0.231881     -0.051599
# 22298   0.866005       0.988332 -3.275813e-01    -0.231881     -0.051599
# 15636  -0.730900      -0.167747  2.870981e+00    -0.231881      1.094355
# 5497   -1.529352      -0.167747 -3.275813e-01    -0.231881     -0.051599
#
#        education  workclass_state-gov  workclass_private  \
# id
# 12849        3.0                  0.0                1.0
# 1460        15.0                  0.0                1.0
# 13594        4.0                  0.0                1.0
# 14400        4.0                  0.0                1.0
# 14333        4.0                  0.0                1.0
# ...          ...                  ...                ...
# 21121        4.0                  0.0                1.0
# 12348        3.0                  0.0                1.0
# 22298        3.0                  0.0                1.0
# 15636        2.0                  0.0                1.0
# 5497         2.0                  0.0                1.0
#
#        workclass_self-emp-inc  workclass_self-emp-not-inc  ...  \
# id                                                         ...
# 12849                     0.0                         0.0  ...
# 1460                      0.0                         0.0  ...
# 13594                     0.0                         0.0  ...
# 14400                     0.0                         0.0  ...
# 14333                     0.0                         0.0  ...
# ...                       ...                         ...  ...
# 21121                     0.0                         0.0  ...
# 12348                     0.0                         0.0  ...
# 22298                     0.0                         0.0  ...
# 15636                     0.0                         0.0  ...
# 5497                      0.0                         0.0  ...
#
#        relationship_wife  relationship_other-relative  race_white  race_black  \
# id
# 12849                0.0                          0.0         1.0         0.0
# 1460                 0.0                          0.0         1.0         0.0
# 13594                0.0                          0.0         0.0         1.0
# 14400                0.0                          0.0         0.0         0.0
# 14333                0.0                          0.0         1.0         0.0
# ...                  ...                          ...         ...         ...
# 21121                0.0                          0.0         1.0         0.0
# 12348                0.0                          0.0         1.0         0.0
# 22298                0.0                          0.0         0.0         1.0
# 15636                0.0                          0.0         1.0         0.0
# 5497                 0.0                          0.0         1.0         0.0
#
#        race_asian-pac-islander  race_other  race_amer-indian-eskimo  sex_male  \
# id
# 12849                      0.0         0.0                      0.0       0.0
# 1460                       0.0         0.0                      0.0       1.0
# 13594                      0.0         0.0                      0.0       0.0
# 14400                      0.0         0.0                      1.0       0.0
# 14333                      0.0         0.0                      0.0       1.0
# ...                        ...         ...                      ...       ...
# 21121                      0.0         0.0                      0.0       1.0
# 12348                      0.0         0.0                      0.0       0.0
# 22298                      0.0         0.0                      0.0       1.0
# 15636                      0.0         0.0                      0.0       1.0
# 5497                       0.0         0.0                      0.0       1.0
#
#        sex_female  label
# id
# 12849         1.0    1.0
# 1460          0.0    0.0
# 13594         1.0    0.0
# 14400         1.0    0.0
# 14333         0.0    1.0
# ...           ...    ...
# 21121         0.0    1.0
# 12348         1.0    1.0
# 22298         0.0    0.0
# 15636         0.0    1.0
# 5497          0.0    0.0
#
# [4180 rows x 49 columns]

# %%
model = joblib.load('../model/modelRF.joblib')
model
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
predictions = model.predict(
X = data_test.drop(['label'], axis = 'columns')
)
predictions
# Out:
# array([0., 0., 0., ..., 1., 1., 0.])

# %%
data_test['prediction'] = predictions
data_test
# Out:
#        age-group  education-num   capitalgain  capitalloss  hoursperweek  \
# id
# 12849  -0.730900       0.988332  1.804794e+00    -0.231881     -0.051599
# 1460   -1.529352      -3.635984 -3.275813e-01    -0.231881      1.094355
# 13594   0.067553      -0.553107 -3.275813e-01    -0.231881     -0.051599
# 14400   0.866005      -0.553107  5.918530e-17    -0.231881     -0.051599
# 14333   0.067553      -0.553107 -3.275813e-01    -0.231881      1.094355
# ...          ...            ...           ...          ...           ...
# 21121   0.866005      -0.553107 -3.275813e-01    -0.231881     -0.051599
# 12348   0.067553       0.988332  3.937169e+00    -0.231881     -0.051599
# 22298   0.866005       0.988332 -3.275813e-01    -0.231881     -0.051599
# 15636  -0.730900      -0.167747  2.870981e+00    -0.231881      1.094355
# 5497   -1.529352      -0.167747 -3.275813e-01    -0.231881     -0.051599
#
#        education  workclass_state-gov  workclass_private  \
# id
# 12849        3.0                  0.0                1.0
# 1460        15.0                  0.0                1.0
# 13594        4.0                  0.0                1.0
# 14400        4.0                  0.0                1.0
# 14333        4.0                  0.0                1.0
# ...          ...                  ...                ...
# 21121        4.0                  0.0                1.0
# 12348        3.0                  0.0                1.0
# 22298        3.0                  0.0                1.0
# 15636        2.0                  0.0                1.0
# 5497         2.0                  0.0                1.0
#
#        workclass_self-emp-inc  workclass_self-emp-not-inc  ...  \
# id                                                         ...
# 12849                     0.0                         0.0  ...
# 1460                      0.0                         0.0  ...
# 13594                     0.0                         0.0  ...
# 14400                     0.0                         0.0  ...
# 14333                     0.0                         0.0  ...
# ...                       ...                         ...  ...
# 21121                     0.0                         0.0  ...
# 12348                     0.0                         0.0  ...
# 22298                     0.0                         0.0  ...
# 15636                     0.0                         0.0  ...
# 5497                      0.0                         0.0  ...
#
#        relationship_other-relative  race_white  race_black  \
# id
# 12849                          0.0         1.0         0.0
# 1460                           0.0         1.0         0.0
# 13594                          0.0         0.0         1.0
# 14400                          0.0         0.0         0.0
# 14333                          0.0         1.0         0.0
# ...                            ...         ...         ...
# 21121                          0.0         1.0         0.0
# 12348                          0.0         1.0         0.0
# 22298                          0.0         0.0         1.0
# 15636                          0.0         1.0         0.0
# 5497                           0.0         1.0         0.0
#
#        race_asian-pac-islander  race_other  race_amer-indian-eskimo  sex_male  \
# id
# 12849                      0.0         0.0                      0.0       0.0
# 1460                       0.0         0.0                      0.0       1.0
# 13594                      0.0         0.0                      0.0       0.0
# 14400                      0.0         0.0                      1.0       0.0
# 14333                      0.0         0.0                      0.0       1.0
# ...                        ...         ...                      ...       ...
# 21121                      0.0         0.0                      0.0       1.0
# 12348                      0.0         0.0                      0.0       0.0
# 22298                      0.0         0.0                      0.0       1.0
# 15636                      0.0         0.0                      0.0       1.0
# 5497                       0.0         0.0                      0.0       1.0
#
#        sex_female  label  prediction
# id
# 12849         1.0    1.0         0.0
# 1460          0.0    0.0         0.0
# 13594         1.0    0.0         0.0
# 14400         1.0    0.0         0.0
# 14333         0.0    1.0         1.0
# ...           ...    ...         ...
# 21121         0.0    1.0         1.0
# 12348         1.0    1.0         1.0
# 22298         0.0    0.0         1.0
# 15636         0.0    1.0         1.0
# 5497          0.0    0.0         0.0
#
# [4180 rows x 50 columns]

# %%
confusion_m = sklearn.metrics.confusion_matrix(
y_true = data_test['label'],
y_pred = data_test['prediction'],
)
confusion_m
# Out:
# array([[1990,  426],
#        [ 393, 1371]])

# %%
pandas.DataFrame(sklearn.metrics.classification_report(
y_true = data_test['label'],
y_pred = data_test['prediction'],
output_dict = True))
# Out:
#                    0.0          1.0  accuracy    macro avg  weighted avg
# precision     0.835082     0.762938  0.804067     0.799010      0.804637
# recall        0.823675     0.777211  0.804067     0.800443      0.804067
# f1-score      0.829339     0.770008  0.804067     0.799674      0.804301
# support    2416.000000  1764.000000  0.804067  4180.000000   4180.000000

# %%
scores = {
    'precision': {
        '0.0': 0.835082,
        '1.0': 0.762938	,
        'macro_avg': 0.799010,
        'weighted_avg': 0.804637
    },
    'recall': {
        '0.0': 0.823675,
        '1.0': 0.786281	,
        'macro_avg': 0.800443	,
        'weighted_avg': 0.800443	
    },
    'f1-score': {
        '0.0': 0.829339,
        '1.0': 0.770008,
        'macro_avg': 0.799674,
        'weighted_avg': 0.804301
    },
    'support': {
        '0.0': 2416.000000,
        '1.0': 1764.000000,
        'total': 4180.000000	
    },
    'accuracy':0.804067	
}

# %%
with open('../results/scoresRF.test.json', 'w') as file:
    json.dump(scores, file)
