# %%
import numpy as np 
import pandas as pd
import joblib
import seaborn
# %matplotlib inline

# %%
data_train = pd.read_csv('../data/features.train.csv').set_index('id')
data_train
# Out:
#        age-group  education-num  capitalgain  capitalloss  hoursperweek  \
# id
# 26890   0.866005       2.144410    -0.327581    -0.231881      1.094355
# 933     0.866005       1.373691     3.937169    -0.231881      1.094355
# 25596   0.067553      -0.167747    -0.327581    -0.231881     -0.051599
# 12949   0.067553       0.988332    -0.327581    -0.231881      1.094355
# 6681   -0.730900      -0.553107    -0.327581    -0.231881     -0.051599
# ...          ...            ...          ...          ...           ...
# 8695   -1.529352      -0.167747    -0.327581    -0.231881     -0.051599
# 2192    0.067553      -0.167747     1.804794    -0.231881     -0.051599
# 8250   -1.529352      -0.553107    -0.327581    -0.231881     -0.051599
# 18511   0.067553       1.373691    -0.327581    -0.231881     -2.343509
# 16074   0.067553      -0.938466    -0.327581    -0.231881      1.094355
#
#        education  workclass_state-gov  workclass_private  \
# id
# 26890        0.0                  1.0                0.0
# 933          1.0                  0.0                1.0
# 25596        2.0                  0.0                1.0
# 12949        3.0                  0.0                1.0
# 6681         4.0                  0.0                1.0
# ...          ...                  ...                ...
# 8695         2.0                  0.0                1.0
# 2192         2.0                  0.0                0.0
# 8250         4.0                  0.0                1.0
# 18511        1.0                  0.0                1.0
# 16074        6.0                  0.0                0.0
#
#        workclass_self-emp-inc  workclass_self-emp-not-inc  ...  \
# id                                                         ...
# 26890                     0.0                         0.0  ...
# 933                       0.0                         0.0  ...
# 25596                     0.0                         0.0  ...
# 12949                     0.0                         0.0  ...
# 6681                      0.0                         0.0  ...
# ...                       ...                         ...  ...
# 8695                      0.0                         0.0  ...
# 2192                      0.0                         0.0  ...
# 8250                      0.0                         0.0  ...
# 18511                     0.0                         0.0  ...
# 16074                     0.0                         1.0  ...
#
#        relationship_wife  relationship_other-relative  race_white  race_black  \
# id
# 26890                0.0                          0.0         1.0         0.0
# 933                  0.0                          0.0         1.0         0.0
# 25596                0.0                          0.0         1.0         0.0
# 12949                0.0                          0.0         1.0         0.0
# 6681                 0.0                          0.0         1.0         0.0
# ...                  ...                          ...         ...         ...
# 8695                 0.0                          0.0         1.0         0.0
# 2192                 0.0                          0.0         1.0         0.0
# 8250                 0.0                          1.0         0.0         1.0
# 18511                0.0                          0.0         1.0         0.0
# 16074                0.0                          0.0         0.0         0.0
#
#        race_asian-pac-islander  race_other  race_amer-indian-eskimo  sex_male  \
# id
# 26890                      0.0         0.0                      0.0       1.0
# 933                        0.0         0.0                      0.0       1.0
# 25596                      0.0         0.0                      0.0       0.0
# 12949                      0.0         0.0                      0.0       1.0
# 6681                       0.0         0.0                      0.0       1.0
# ...                        ...         ...                      ...       ...
# 8695                       0.0         0.0                      0.0       1.0
# 2192                       0.0         0.0                      0.0       1.0
# 8250                       0.0         0.0                      0.0       1.0
# 18511                      0.0         0.0                      0.0       1.0
# 16074                      1.0         0.0                      0.0       1.0
#
#        sex_female  label
# id
# 26890         0.0    1.0
# 933           0.0    1.0
# 25596         1.0    0.0
# 12949         0.0    1.0
# 6681          0.0    0.0
# ...           ...    ...
# 8695          0.0    0.0
# 2192          0.0    0.0
# 8250          0.0    0.0
# 18511         0.0    1.0
# 16074         0.0    0.0
#
# [16720 rows x 49 columns]

# %%
model = joblib.load('../model/modelRF.joblib')
model
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
feature_importance = pd.DataFrame({
    'feature_name': model.feature_names_in_,
    'feature_importance': model.feature_importances_,
})

feature_importance.sort_values(
    by = 'feature_importance', 
    ascending = False,
    inplace = True
)
feature_importance
# Out:
#                             feature_name  feature_importance
# 0                              age-group        1.277119e-01
# 1                          education-num        1.030424e-01
# 16     marital-status_married-civ-spouse        1.000923e-01
# 2                            capitalgain        9.141667e-02
# 4                           hoursperweek        8.590974e-02
# 5                              education        6.021409e-02
# 38                  relationship_husband        5.172705e-02
# 15          marital-status_never-married        4.189728e-02
# 3                            capitalloss        2.784696e-02
# 21             occupation_prof-specialty        1.919479e-02
# 35                relationship_own-child        1.781750e-02
# 7                      workclass_private        1.699236e-02
# 23            occupation_exec-managerial        1.682324e-02
# 37            relationship_not-in-family        1.447835e-02
# 28              occupation_other-service        1.268021e-02
# 9             workclass_self-emp-not-inc        1.172472e-02
# 39                     relationship_wife        1.164153e-02
# 46                              sex_male        1.158552e-02
# 25                      occupation_sales        1.134337e-02
# 41                            race_white        1.130074e-02
# 47                            sex_female        1.084333e-02
# 27               occupation_craft-repair        1.054518e-02
# 36                relationship_unmarried        1.049576e-02
# 29               occupation_adm-clerical        1.046695e-02
# 11                   workclass_local-gov        1.000643e-02
# 14               marital-status_divorced        9.048301e-03
# 42                            race_black        8.373415e-03
# 8                 workclass_self-emp-inc        8.154441e-03
# 6                    workclass_state-gov        8.043482e-03
# 30           occupation_transport-moving        7.425802e-03
# 32            occupation_farming-fishing        7.424097e-03
# 24          occupation_machine-op-inspct        7.259371e-03
# 22               occupation_tech-support        6.710344e-03
# 43               race_asian-pac-islander        6.388777e-03
# 10                 workclass_federal-gov        6.360406e-03
# 26          occupation_handlers-cleaners        5.344930e-03
# 31            occupation_protective-serv        5.237524e-03
# 17              marital-status_separated        3.256269e-03
# 40           relationship_other-relative        3.195450e-03
# 18                marital-status_widowed        2.782206e-03
# 45               race_amer-indian-eskimo        2.423547e-03
# 19  marital-status_married-spouse-absent        1.811377e-03
# 44                            race_other        1.391476e-03
# 20      marital-status_married-af-spouse        9.151869e-04
# 33            occupation_priv-house-serv        4.086118e-04
# 12                 workclass_without-pay        2.020477e-04
# 34               occupation_armed-forces        4.434013e-05
# 13                workclass_never-worked        1.766838e-07

# %%
seaborn.set(
    style = 'whitegrid', 
    rc    = {'figure.figsize': (10, 20)}
)

seaborn.barplot(
    data=feature_importance,
    x='feature_importance', 
    y='feature_name'
)
# Out:
# <Axes: xlabel='feature_importance', ylabel='feature_name'>
