# %%
import joblib
import json
import pandas as pd 
import sklearn.ensemble

# %%
data_train = pd.read_csv('./data/features.train.csv').set_index('id')
data_train
# Out:
#        social-security-number  house-number  age-group    fnlwgt  \
# id
# 26890                1.676806      0.010066   0.889085  1.327530
# 933                  1.279450      0.485531   0.889085 -0.866107
# 25596               -0.596648      1.414386   0.073231  2.007197
# 12949                0.107424     -1.620247   0.073231  4.741403
# 6681                 1.093883     -1.137775  -0.742622  0.452335
# ...                       ...           ...        ...       ...
# 8695                -1.427742     -1.638467  -1.558476 -1.414445
# 2192                 0.940709     -1.432094   0.073231 -0.827427
# 8250                 0.271229      1.279490  -1.558476  1.215017
# 18511               -0.823986      0.070332   0.073231  2.809195
# 16074                0.405181      1.299111   0.073231 -1.103316
#
#        education-num  capitalgain  capitalloss  hoursperweek  workclass  \
# id
# 26890       2.151965    -0.329532     -0.23238      1.083594        0.0
# 933         1.374304     3.898612     -0.23238      1.083594        1.0
# 25596      -0.181017    -0.329532     -0.23238     -0.096050        1.0
# 12949       0.985474    -0.329532     -0.23238      1.083594        1.0
# 6681       -0.569847    -0.329532     -0.23238     -0.096050        1.0
# ...              ...          ...          ...           ...        ...
# 8695       -0.181017    -0.329532     -0.23238     -0.096050        1.0
# 2192       -0.181017     1.784540     -0.23238     -0.096050        5.0
# 8250       -0.569847    -0.329532     -0.23238     -0.096050        1.0
# 18511       1.374304    -0.329532     -0.23238     -2.455338        1.0
# 16074      -0.958677    -0.329532     -0.23238      1.083594        3.0
#
#        education  ...  native-country_ireland  native-country_france  \
# id                ...
# 26890        0.0  ...                     0.0                    0.0
# 933          1.0  ...                     0.0                    0.0
# 25596        2.0  ...                     0.0                    0.0
# 12949        3.0  ...                     0.0                    0.0
# 6681         4.0  ...                     0.0                    0.0
# ...          ...  ...                     ...                    ...
# 8695         2.0  ...                     0.0                    0.0
# 2192         2.0  ...                     0.0                    0.0
# 8250         4.0  ...                     0.0                    0.0
# 18511        1.0  ...                     0.0                    0.0
# 16074        6.0  ...                     0.0                    0.0
#
#        native-country_outlying-us(guam-usvi-etc)  native-country_hong  \
# id
# 26890                                        0.0                  0.0
# 933                                          0.0                  0.0
# 25596                                        0.0                  0.0
# 12949                                        0.0                  0.0
# 6681                                         0.0                  0.0
# ...                                          ...                  ...
# 8695                                         0.0                  0.0
# 2192                                         0.0                  0.0
# 8250                                         0.0                  0.0
# 18511                                        0.0                  0.0
# 16074                                        0.0                  0.0
#
#        native-country_nicaragua  native-country_honduras  \
# id
# 26890                       0.0                      0.0
# 933                         0.0                      0.0
# 25596                       0.0                      0.0
# 12949                       0.0                      0.0
# 6681                        0.0                      0.0
# ...                         ...                      ...
# 8695                        0.0                      0.0
# 2192                        0.0                      0.0
# 8250                        0.0                      0.0
# 18511                       0.0                      0.0
# 16074                       0.0                      0.0
#
#        native-country_thailand  native-country_holand-netherlands  \
# id
# 26890                      0.0                                0.0
# 933                        0.0                                0.0
# 25596                      0.0                                0.0
# 12949                      0.0                                0.0
# 6681                       0.0                                0.0
# ...                        ...                                ...
# 8695                       0.0                                0.0
# 2192                       0.0                                0.0
# 8250                       0.0                                0.0
# 18511                      0.0                                0.0
# 16074                      0.0                                0.0
#
#        native-country_scotland  label
# id
# 26890                      0.0    1.0
# 933                        0.0    1.0
# 25596                      0.0    0.0
# 12949                      0.0    1.0
# 6681                       0.0    0.0
# ...                        ...    ...
# 8695                       0.0    0.0
# 2192                       0.0    0.0
# 8250                       0.0    0.0
# 18511                      0.0    1.0
# 16074                      0.0    0.0
#
# [15352 rows x 155 columns]

# %%
model = sklearn.ensemble.RandomForestClassifier(
    criterion    = 'entropy',
    random_state = 0
)
model
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
X_train = data_train.drop(['label'], axis = 'columns')
y_train = data_train['label']

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
joblib.dump(model, './model/model.joblib')
# Out:
# ['./model/model.joblib']

# %%
config = model.get_params()

# %%
with open('./model/config.json', 'w') as f:
    json.dump(config, f, indent=4)
