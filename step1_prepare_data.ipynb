# %%
import numpy as np
import pandas as pd
import sklearn.model_selection

# %%
data = pd.read_csv('../work/data/high_salary.csv')
data
# Out:
#           id  social-security-number  house-number  age-group     workclass  \
# 0       8616             552701574.0        9854.0        2.0  self-emp-inc
# 1      21982             956556990.0        7588.0        3.0     local-gov
# 2      11191             958358623.0        6729.0        0.0       private
# 3      22229             224206693.0        6288.0        2.0       private
# 4      20732             276413230.0        8276.0        3.0       private
# ...      ...                     ...           ...        ...           ...
# 20895  21575             263539011.0        7910.0        0.0       private
# 20896   5390             590882568.0        6432.0        3.0       private
# 20897    860             289157658.0        2008.0        3.0       private
# 20898  15795             363933621.0        4726.0        0.0     state-gov
# 20899  23654             185635080.0        5278.0        4.0       private
#
# ...

# %%
data_train, data_test = sklearn.model_selection.train_test_split(
    data,
    train_size   = 0.80,
    shuffle      = True ,
    random_state = 0
)

# %%
data_train.to_csv('./data/high_salary_train.csv')
data_test.to_csv('./data/high_salary_test.csv')
