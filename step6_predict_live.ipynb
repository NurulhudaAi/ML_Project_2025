# %%
import pandas
import joblib

# %%
data_live_features = pandas.read_csv('./data/features.live.csv').set_index('id')
data_live_features
# Out:
#        age-group  education-num  capitalgain  capitalloss  hoursperweek  \
# id
# 6111   -1.558476      -1.347508    -0.329532     -0.23238     -0.096050
# 11214  -0.742622      -0.569847    -0.329532     -0.23238     -1.275694
# 5554    1.704938      -0.569847    -0.329532     -0.23238      1.083594
# 25131   0.073231       1.374304    -0.329532     -0.23238     -0.096050
# 14324   0.889085      -0.569847    -0.329532     -0.23238     -0.096050
# ...          ...            ...          ...          ...           ...
# 15056   0.889085      -0.181017    -0.329532     -0.23238     -1.275694
# 25998   1.704938       0.985474    -0.329532     -0.23238      1.083594
# 8375    1.704938      -0.569847    -0.329532     -0.23238      2.263238
# 13888  -0.742622      -1.347508    -0.329532     -0.23238     -1.275694
# 4159   -0.742622       1.374304    -0.329532     -0.23238     -0.096050
#
#        workclass  education  marital-status  occupation  relationship  ...  \
# ...

# %%
model = joblib.load('./model/model.joblib')
model
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
# data_live_predictions= pandas.DataFrame(
#     data= model.predict(data_live_features),
#    index=data_live_features.index,
#    columns=['predictions']
# )
# data_live_predictions
# Out:
#        predictions
# id
# 6111           0.0
# 11214          0.0
# 5554           1.0
# 25131          1.0
# 14324          1.0
# ...            ...
# 15056          1.0
# 25998          1.0
# 8375           0.0
# 13888          0.0
# 4159           1.0
#
# [6389 rows x 1 columns]

# %%
data_live_predictions= pandas.DataFrame({
  'id': data_live_features.index,
'prediction': model.predict(data_live_features)
})
data_live_predictions
# Out:
#          id  prediction
# 0      6111         0.0
# 1     11214         0.0
# 2      5554         1.0
# 3     25131         1.0
# 4     14324         1.0
# ...     ...         ...
# 6384  15056         1.0
# 6385  25998         1.0
# 6386   8375         0.0
# 6387  13888         0.0
# 6388   4159         1.0
#
# [6389 rows x 2 columns]

# %%
data_live_predictions= pandas.DataFrame(
    data= model.predict(data_live_features),
   index=data_live_features.index,
   columns=['prediction']).reset_index()
data_live_predictions.columns = ['id', 'predictions']

data_live_predictions
# Out:
#          id  predictions
# 0      6111          0.0
# 1     11214          0.0
# 2      5554          1.0
# 3     25131          1.0
# 4     14324          1.0
# ...     ...          ...
# 6384  15056          1.0
# 6385  25998          1.0
# 6386   8375          0.0
# 6387  13888          0.0
# 6388   4159          1.0
#
# [6389 rows x 2 columns]
